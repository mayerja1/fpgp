# %%
# %load_ext autoreload
# %autoreload 2
import symb_reg as sr
import fitness_pred
import matplotlib.pyplot as plt
from deap import tools
from symb_reg_toolbox import toolbox
import numpy as np

# %%
stats = sr.symb_reg_initialize()

# %%
# %%time
_, log, hof = sr.run('gen', lambda x: x >= 2000, 'exact')
# Out:
# CPU times: user 3min 33s, sys: 284 ms, total: 3min 33s
# Wall time: 3min 33s

# %%
target_vals = np.array([sr.target_func(p) for p in sr.TRAINING_SET])
plt.scatter(sr.TRAINING_SET, target_vals)
plt.plot(sr.TRAINING_SET, hof[0].values)

# %%
hof[0].fitness
# Out:
# deap.creator.FitnessMin((0.53788793379128,))

# %%
plt.plot(range(2000), log.chapters['height'].select('avg'))

# %%
plt.plot(range(2000), [-l['test_set_f'] for l in log])
